# %% [markdown]
# ### import and path

# %%
import socket
import sys
import pickle
import os
import time
from pprint import pprint

root_dir = '/tmp/drl_urban_planning'

# %% [markdown]
# ### demo

# %%
from urban_planning.envs import CityEnv
from urban_planning.envs import city_config
from urban_planning.utils.config import Config

# %%
id = 'hlg'
seed = 111
temp = False
cfg = Config(id, seed, temp, root_dir)
env = CityEnv(cfg)

# %%
model_path = os.path.join(root_dir, id, str(seed), 'models', 'best.p')
d = pickle.load(open(model_path, 'rb'))
gdf = d['best_plans'][0]['gdf']
print(d['best_plans'][0])
# Out:
# {'road_network': -1.0, 'life_circle': 0.421123132501423, 'greenness': 0.6608256100775974, 'concept': -1.0, 'life_circle_info': {'life_circle_15min': 0.86, 'life_circle_10min': 0.41000000000000003, 'life_circle_5min': 0.22000000000000003, 'life_circle_10min_area': 0.3906901484321008, 'decentralization_reward': 0.22246265002846027, 'utility': 0.15951779900731172, 'shopping': 0.45, 'working': 0.65, 'education': 0.3, 'medical care': 0.35, 'entertainment': 0.3}, 'concept_info': {}, 'land_use_reward': 2.3453181400832896, 'gdf':      type  existence                                           geometry  \
# id
# 0       2       True          LINESTRING (440.000 0.000, 820.000 0.000)
# 1       2      False  LINESTRING (820.000 0.000, 980.000 0.000, 1130...
# 2       2       True        LINESTRING (1280.000 0.000, 1700.000 0.000)
# 3       2       True        LINESTRING (1700.000 0.000, 2160.000 0.000)
# 4       2       True      LINESTRING (0.000 1860.000, 100.000 1540.000)
# ..    ...        ...                                                ...
# 348     2       True  LINESTRING (1635.000 1445.000, 1435.000 1445.000)
# 349     2       True  LINESTRING (1435.000 1360.000, 1435.000 1445.000)
# 350     5       True  POLYGON ((1435.000 1445.000, 1635.000 1445.000...
# 351     1      False  POLYGON ((1435.000 1445.000, 1435.000 1360.000...
# 352     5       True  POLYGON ((1435.000 1445.000, 1435.000 1360.000...
#
#          rect       eqi        sc
# id
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# ..        ...       ...       ...
# 348       NaN       NaN       NaN
# 349       NaN       NaN       NaN
# 350  0.987805  1.002270  0.832542
# 351  0.982456  1.003961  0.713434
# 352  0.982456  1.003961  0.713434
#
# [353 rows x 6 columns], 'land_use_gdf':      type  existence                                           geometry  \
# id
# 0       2       True          LINESTRING (440.000 0.000, 820.000 0.000)
# 1       2      False  LINESTRING (820.000 0.000, 980.000 0.000, 1130...
# 2       2       True        LINESTRING (1280.000 0.000, 1700.000 0.000)
# 3       2       True        LINESTRING (1700.000 0.000, 2160.000 0.000)
# 4       2       True      LINESTRING (0.000 1860.000, 100.000 1540.000)
# ..    ...        ...                                                ...
# 348     2       True  LINESTRING (1635.000 1445.000, 1435.000 1445.000)
# 349     3       True  LINESTRING (1435.000 1360.000, 1435.000 1445.000)
# 350     5       True  POLYGON ((1435.000 1445.000, 1635.000 1445.000...
# 351     1      False  POLYGON ((1435.000 1445.000, 1435.000 1360.000...
# 352     5       True  POLYGON ((1435.000 1445.000, 1435.000 1360.000...
#
#          rect       eqi        sc
# id
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# ..        ...       ...       ...
# 348       NaN       NaN       NaN
# 349       NaN       NaN       NaN
# 350  0.987805  1.002270  0.832542
# 351  0.982456  1.003961  0.713434
# 352  0.982456  1.003961  0.713434
#
# [353 rows x 6 columns]}

# %% [markdown]
# ### load plan and score

# %%
env.load_plan(gdf)
env.score_plan()
# Out:
# reward: 2.3453181400832896
# {   'road_network': -1.0,
#     'life_circle': 0.421123132501423,
#     'greenness': 0.6608256100775974,
#     'road_network_info': {},
#     'life_circle_info': {   'life_circle_15min': 0.86,
#                             'life_circle_10min': 0.41000000000000003,
#                             'life_circle_5min': 0.22000000000000003,
#                             'life_circle_10min_area': 0.3906901484321008,
#                             'decentralization_reward': 0.22246265002846027,
#                             'utility': 0.15951779900731172,
#                             'shopping': 0.45,
#                             'working': 0.65,
#                             'education': 0.3,
#                             'medical care': 0.35,
#                             'entertainment': 0.3}}
# (2.3453181400832896,
#  {'road_network': -1.0,
#   'life_circle': 0.421123132501423,
#   'greenness': 0.6608256100775974,
#   'road_network_info': {},
#   'life_circle_info': {'life_circle_15min': 0.86,
#    'life_circle_10min': 0.41000000000000003,
#    'life_circle_5min': 0.22000000000000003,
#    'life_circle_10min_area': 0.3906901484321008,
#    'decentralization_reward': 0.22246265002846027,
#    'utility': 0.15951779900731172,
#    'shopping': 0.45,
#    'working': 0.65,
#    'education': 0.3,
#    'medical care': 0.35,
#    'entertainment': 0.3}})

# %%
env.visualize()

# %%
env.visualize_road_and_boundary()
